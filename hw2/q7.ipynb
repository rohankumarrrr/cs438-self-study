# %%
import numpy as np
import matplotlib.pyplot as plt
from collections import deque

DURATION = 1000 # Seconds per session
TICKS_PER_SECOND = 10 # 0.1 second per tick
TOTAL_TICKS = DURATION * TICKS_PER_SECOND # Total ticks per session
ROUTER_SERVICE_RATE = 10 # Packets per second
NUM_SEEDS = 20 # Number of different seeds to simulate

# %%
# A values to simulate: 0 to 10 (inclusive).
A_values = list(range(11))
results = {
    'x_axis' : [],
    'avg_qd_mean': [],
    'avg_qd_25': [],
    'avg_q_mean': []
}

# %%
# Simulation function
def run_simulation(arrival_rate, seed):
# Out:
#   Cell In[2], line 2
#     def run_simulation(arrival_rate, seed):
#                                            ^
# SyntaxError: incomplete input
